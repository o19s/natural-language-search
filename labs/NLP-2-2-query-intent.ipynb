# %%
# !python -m spacy download en_core_web_lg
# Out:
# Requirement already satisfied: en_core_web_lg==2.1.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.1.0/en_core_web_lg-2.1.0.tar.gz#egg=en_core_web_lg==2.1.0 in /usr/local/lib/python3.6/dist-packages (2.1.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_lg')

# %%
import spacy
import requests
import datetime
import json
nlp = spacy.load('en')

# %%
def print_intent(params):
    text = params[0]
    intent = params[1]
    predicate = params[2]
    objects = params[3]
    if not intent:
        print('No intent for "' + text + '", found "' + predicate.text + '" as the root.')
    else:
        print(text,'==>',intent,objects)

    print('-----------------')

# %%
test = [
    ("the movie was directed by george clooney","direct"),
    ("movies directed by george clooney","direct"),
    ("movies by george clooney","direct"),
    ("directed by george clooney","direct"),
    ("george clooney director","direct"),
    ("george clooney directing with brad pitt","direct"),
    ("george clooney directed brad pitt","direct"),
    ("george clooney directed by brad pitt","direct"),
    ("The movie stars george clooney","star"),
    ("starring george clooney","star"),
    ("george clooney starred","star"),
    ("george clooney star","star"),
    ("costarring george clooney and brad pitt","costar"),
    ("george clooney and brad pitt","costar"),
    ("george clooney with brad pitt","costar"),
    ("best george clooney movie","best"),
    ("best movie of 2012","best"),
    ("Tom Hanks' best movie","best"),
    ("popular julia roberts","best"),
    ("2012 worst","worst"),
    ("panned julia roberts","worst"),
    ("bad julia roberts","worst")
]

# %% [markdown]
# ## Let's get the root!
#
# We use the **root** of the sentence/clause as the predicate in the subject-predicate-object structure.

# %%
def intent_from_root(text):
    doc = nlp(text)
    intent = None
    predicate = None
    objects = [ent.text for ent in doc.ents]
    
    predicate_taxonomy = {
        'directed':['direct','director','by'],
        'cast':['star','feature','cameo','costarring']
    }
        
    #get root of the clause
    for tok in doc:
        if tok.dep_ == "ROOT":
            predicate = tok
    
    #See if the intent is in the taxonomy
    for kind in predicate_taxonomy.keys():
        if predicate.lemma_ in predicate_taxonomy[kind]:
            intent = kind
            
    return [text,intent,predicate,objects]

for t in test:
    print_intent(intent_from_root(t[0]))
# Out:
# the movie was directed by george clooney ==> directed []
# -----------------
# No intent for "movies directed by george clooney", found "movies" as the root.
# -----------------
# No intent for "movies by george clooney", found "movies" as the root.
# -----------------
# directed by george clooney ==> directed []
# -----------------
# george clooney director ==> directed []
# -----------------
# No intent for "george clooney directing with brad pitt", found "clooney" as the root.
# -----------------
# george clooney directed brad pitt ==> directed []
# -----------------
# No intent for "george clooney directed by brad pitt", found "clooney" as the root.
# -----------------
# The movie stars george clooney ==> cast []
# -----------------
# starring george clooney ==> cast []
# -----------------
# george clooney starred ==> cast []
# -----------------
# george clooney star ==> cast []
# -----------------
# No intent for "costarring george clooney and brad pitt", found "costarring" as the root.
# -----------------
# No intent for "george clooney and brad pitt", found "clooney" as the root.
# -----------------
# No intent for "george clooney with brad pitt", found "clooney" as the root.
# -----------------
# No intent for "best george clooney movie", found "movie" as the root.
# -----------------
# No intent for "best movie of 2012", found "movie" as the root.
# -----------------
# No intent for "Tom Hanks' best movie", found "movie" as the root.
# -----------------
# No intent for "popular julia roberts", found "roberts" as the root.
# -----------------
# No intent for "2012 worst", found "2012" as the root.
# -----------------
# No intent for "panned julia roberts", found "panned" as the root.
# -----------------
# No intent for "bad julia roberts", found "roberts" as the root.
# -----------------

# %%
def intent_from_root2(text):
    doc = nlp(text)
    intent = None
    predicate = None
    objects = [ent.text for ent in doc.ents]
    
    predicate_taxonomy = {
        'directed':['direct','director'],
        'cast':['star','feature','cameo']
    }
        
    #get root of the clause
    for tok in doc:
        print(tok.text,tok.dep_,tok.pos_)
        if tok.dep_ == "ROOT":
            predicate = tok
    
    print(predicate,objects)
    
    #See if the intent is in the taxonomy
    for kind in predicate_taxonomy.keys():
        if predicate.lemma_ in predicate_taxonomy[kind]:
            intent = kind
        
    return [text,intent,predicate,objects]
            
for t in test:
    print_intent(intent_from_root2(t[0]))
# Out:
# the det DET
# movie nsubjpass NOUN
# was auxpass VERB
# directed ROOT VERB
# by agent ADP
# george compound NOUN
# clooney pobj NOUN
# directed []
# the movie was directed by george clooney ==> directed []
# -----------------
# movies ROOT NOUN
# directed acl VERB
# by agent ADP
# george compound NOUN
# clooney pobj NOUN
# movies []
# No intent for "movies directed by george clooney", found "movies" as the root.
# -----------------
# movies ROOT NOUN
# by prep ADP
# george compound NOUN
# clooney pobj NOUN
# movies []
# No intent for "movies by george clooney", found "movies" as the root.
# -----------------
# directed ROOT VERB
# by agent ADP
# george compound NOUN
# clooney pobj NOUN
# directed []
# directed by george clooney ==> directed []
# -----------------
# george compound NOUN
# clooney compound NOUN
# director ROOT NOUN
# director []
# george clooney director ==> directed []
# -----------------
# george compound NOUN
# clooney ROOT NOUN
# directing acl VERB
# with prep ADP
# brad amod NOUN
# pitt pobj NOUN
# clooney []
# No intent for "george clooney directing with brad pitt", found "clooney" as the root.
# -----------------
# george compound NOUN
# clooney nsubj NOUN
# directed ROOT VERB
# brad amod NOUN
# pitt dobj NOUN
# directed []
# george clooney directed brad pitt ==> directed []
# -----------------
# george compound NOUN
# clooney ROOT NOUN
# directed acl VERB
# by agent ADP
# brad amod NOUN
# pitt pobj NOUN
# clooney []
# No intent for "george clooney directed by brad pitt", found "clooney" as the root.
# -----------------
# The det DET
# movie nsubj NOUN
# stars ROOT VERB
# george compound NOUN
# clooney dobj NOUN
# stars []
# The movie stars george clooney ==> cast []
# -----------------
# starring ROOT VERB
# george compound NOUN
# clooney dobj NOUN
# starring []
# starring george clooney ==> cast []
# -----------------
# george compound NOUN
# clooney nsubj NOUN
# starred ROOT VERB
# starred []
# george clooney starred ==> cast []
# -----------------
# george compound NOUN
# clooney compound NOUN
# star ROOT NOUN
# star []
# george clooney star ==> cast []
# -----------------
# costarring ROOT VERB
# george compound NOUN
# clooney dobj NOUN
# and cc CCONJ
# brad amod NOUN
# pitt conj NOUN
# costarring []
# No intent for "costarring george clooney and brad pitt", found "costarring" as the root.
# -----------------
# george compound NOUN
# clooney ROOT NOUN
# and cc CCONJ
# brad amod NOUN
# pitt conj NOUN
# clooney []
# No intent for "george clooney and brad pitt", found "clooney" as the root.
# -----------------
# george compound NOUN
# clooney ROOT NOUN
# with prep ADP
# brad amod NOUN
# pitt pobj NOUN
# clooney []
# No intent for "george clooney with brad pitt", found "clooney" as the root.
# -----------------
# best amod ADJ
# george compound ADJ
# clooney compound NOUN
# movie ROOT NOUN
# movie []
# No intent for "best george clooney movie", found "movie" as the root.
# -----------------
# best amod ADJ
# movie ROOT NOUN
# of prep ADP
# 2012 pobj NUM
# movie ['2012']
# No intent for "best movie of 2012", found "movie" as the root.
# -----------------
# Tom compound PROPN
# Hanks poss PROPN
# ' case PART
# best amod ADJ
# movie ROOT NOUN
# movie ["Tom Hanks'"]
# No intent for "Tom Hanks' best movie", found "movie" as the root.
# -----------------
# popular amod ADJ
# julia compound NOUN
# roberts ROOT VERB
# roberts []
# No intent for "popular julia roberts", found "roberts" as the root.
# -----------------
# 2012 ROOT NUM
# worst advmod ADJ
# 2012 ['2012']
# No intent for "2012 worst", found "2012" as the root.
# -----------------
# panned ROOT VERB
# julia compound NOUN
# roberts dobj NOUN
# panned []
# No intent for "panned julia roberts", found "panned" as the root.
# -----------------
# bad amod ADJ
# julia compound NOUN
# roberts ROOT VERB
# roberts []
# No intent for "bad julia roberts", found "roberts" as the root.
# -----------------
